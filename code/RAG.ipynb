# %%
# !pip install python-dotenv

# %%
from google.colab import drive
import os
from dotenv import load_dotenv
import pandas as pd

drive.mount('/content/drive')
env_path = '/content/drive/MyDrive/rag_project/.env'
load_dotenv(env_path)

github_username = os.getenv('GITHUB_USERNAME')
github_token = os.getenv('GITHUB_TOKEN')
repository_name = os.getenv('REPOSITORY_NAME')

github_url = f"https://{github_username}:{github_token}@github.com/{github_username}/{repository_name}.git"

api_key = os.getenv('LANGCHAIN_API_KEY')
project_name = os.getenv('LANGCHAIN_PROJECT')

doc = pd.read_csv('/content/drive/MyDrive/rag_project/last_df.csv')
doc.head()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#     Question                                             Answer
# 0  면진장치가 뭐야?  면진장치란 지반에서 오는 진동 에너지를 흡수하여 건물에 주는 진동을 줄여주는 진동 ...
# 1  면진장치가 뭐야?  면진장치란 건물의 지반에서 발생하는 진동 에너지를 흡수하여 건물을 보호하고, 진동을...
# 2  면진장치가 뭐야?  면진장치란 지반으로부터 발생하는 진동 에너지를 흡수하여 건물에 전달되는 진동을 줄여...
# 3  면진장치가 뭐야?  면진장치는 건물의 지반으로부터 오는 진동 에너지를 흡수하여 건물에 전달되는 진동을 ...
# 4  면진장치가 뭐야?  면진장치는 건물에 오는 지반 진동의 영향을 최대한으로 흡수하여 건물에 전달되는 진동...

# %%
from google.colab import drive
import os
from dotenv import load_dotenv
import pandas as pd
import shutil

# Google Drive 마운트
drive.mount('/content/drive')

# 환경 변수 로드
env_path = '/content/drive/MyDrive/rag_project/.env'
load_dotenv(env_path)

# 환경 변수 가져오기
github_username = os.getenv('GITHUB_USERNAME')
github_token = os.getenv('GITHUB_TOKEN')
repository_name = os.getenv('REPOSITORY_NAME')

# GitHub URL 구성
github_url = f"https://{github_username}:{github_token}@github.com/{github_username}/{repository_name}.git"

# Git 사용자 정보 설정
github_email = f"{github_username}@users.noreply.github.com"
# !git config --global user.name "{github_username}"
# !git config --global user.email "{github_email}"

# 저장소 클론
clone_dir = f"/content/{repository_name}"
# !git clone {github_url} {clone_dir}

# 파일 복사
source_file = '/content/drive/MyDrive/Colab Notebooks/RAG.ipynb'
destination_dir = clone_dir
shutil.copy(source_file, destination_dir)

# 변경 사항 추가
# !git -C {clone_dir} add RAG.ipynb

# 커밋
commit_message = "Add/update RAG.ipynb"
# !git -C {clone_dir} commit -m "{commit_message}"

# 푸시
# !git -C {clone_dir} push origin main
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Cloning into '/content/RAG_project'...
# remote: Enumerating objects: 9, done.
# remote: Counting objects: 100% (9/9), done.
# remote: Compressing objects: 100% (6/6), done.
# remote: Total 9 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (9/9), 50.37 KiB | 805.00 KiB/s, done.
# [main 6751c22] Add/update RAG.ipynb
#  1 file changed, 1 insertion(+)
#  create mode 100644 RAG.ipynb
# Enumerating objects: 4, done.
# Counting objects: 100% (4/4), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (3/3), done.
# Writing objects: 100% (3/3), 1.87 KiB | 1.87 MiB/s, done.
# Total 3 (delta 1), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (1/1), completed with 1 local object.
# To https://github.com/suhyun0115/RAG_project.git
#    e250f85..6751c22  main -> main
